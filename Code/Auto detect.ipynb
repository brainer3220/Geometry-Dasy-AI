# %%
import tensorflow as tf
import tensorflow.keras
import cv2
import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
GRID_SIZE = 30

# %%
image_folder = '..\\Photo\\isPlay\\'

play_folder = image_folder+'GMD Play\\'
miss_folder = image_folder+'GMD Miss\\'

play_list = os.listdir(play_folder)
miss_list = os.listdir(miss_folder)

# %%
tmp_img = cv2.imread(play_folder+play_list[0])

tmp_img = cv2.cvtColor(cv2.resize(tmp_img, (640, 360)), cv2.COLOR_BGR2RGB)
tmp_img.shape
# Out:
# (360, 640, 3)

# %%
plt.imshow(tmp_img)

# %%
arr = np.split(tmp_img, 8)
arr = np.array([np.split(x, 8, 1) for x in arr])

# %%
arr.shape
# Out:
# (8, 8, 45, 80, 3)

# %%
for i in range(1, 8):
    for j in range(1, 8):
        tmp = arr[j-1:j, i-1:i].reshape(45, 80, 3)
        plt.imshow(tmp)
        plt.show()
